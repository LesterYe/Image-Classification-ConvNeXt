# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json

# %%
dir = '/content/drive/MyDrive/CS424 - IP/a2/Image-Classification-ConvNeXt' # Change your working directory here
train_dir = os.path.join(dir, 'train')

# %%
json_dict = {}

count=0 
for file_name in os.listdir(train_dir):
  json_dict[str(count)] = file_name
  count+=1

# %%
json_string = json.dumps(json_dict)
print(json_string)
# Out:
# {"0": "000000", "1": "000001", "2": "000002", "3": "000003", "4": "000004", "5": "000005", "6": "000006", "7": "000007", "8": "000008", "9": "000009", "10": "000010", "11": "000011", "12": "000012", "13": "000013", "14": "000014", "15": "000015", "16": "000016", "17": "000017", "18": "000018", "19": "000019", "20": "a_Capitol", "21": "a_Chijmes", "22": "a_Cityhall", "23": "a_CoffeeShop", "24": "a_HDB", "25": "a_SMUadmin", "26": "a_Underground", "27": "a_cemetry", "28": "a_church", "29": "a_law", "30": "a_library", "31": "a_museum", "32": "a_scis", "33": "americano", "34": "bak_kwa", "35": "beef_noodles_soup", "36": "boiled_clams", "37": "boonthi", "38": "braised_pig_skin", "39": "braised_pig_trotter_with_mushroom", "40": "braised_pork_with_black_fungus", "41": "cafe_coffee_with_milk", "42": "chasoba", "43": "chicken_and_mushroom_noodles_soup", "44": "chicken_feet_noodles_soup", "45": "chicken_macaroni_soup", "46": "cooked_jellyfish_with_sesame_seed", "47": "crab_stick", "48": "curry_udon", "49": "dry_chicken_feet_noodles", "50": "dry_duck_noodles", "51": "duck_noodles_soup", "52": "espresso", "53": "fish_tofu_cheese_tofu", "54": "fishball", "55": "fried_fishcake", "56": "fried_spicy_mussels", "57": "fried_vegetable_samosa", "58": "green_bean_cake", "59": "idli", "60": "instant_coffee", "61": "jalebi", "62": "kebab_wrap", "63": "kopi_o", "64": "local_coffee_with_milk", "65": "lor_bak_nonya_style_simmered_pork", "66": "lotus_paste_with_salted_egg_pastry", "67": "muruku", "68": "onion_bhaji", "69": "otah", "70": "pig_trotter_in_vinegar", "71": "pineapple_tart", "72": "pong_piah", "73": "prawn_tempura_udon_soup", "74": "putu_mayam", "75": "raw_oyster", "76": "red_bean_cake", "77": "red_wine_chicken_mee_sua", "78": "roasted_pork_belly", "79": "roasted_suckling_pig", "80": "sa_kei_ma", "81": "sambal_clams", "82": "sesame_seed_ball", "83": "shredded_chicken_and_mushroom_noodles", "84": "soup_with_mutton", "85": "soya_sauce_chicken_noodles", "86": "steamed_minced_pork_with_fish_mushroom_and_preserved_veg", "87": "stir_fried_pork", "88": "stir_fried_udon", "89": "sup_tulang", "90": "sweet_and_sour_meat", "91": "taco"}

# %%
os.chdir(dir)

# %%
with open('label_to_words.json', 'w') as outfile:
  json.dump(json_dict, outfile)
