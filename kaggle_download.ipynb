# %% [markdown]
# [Kaggle Guide](https://www.kaggle.com/general/156610)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# %%
dir = '/content/gdrive/MyDrive/CS424 - IP/a2/Image-Classification-ConvNeXt'
os.chdir(dir)

# %%
from google.colab import files

files.upload() #this will prompt you to upload the kaggle.json
# Out:
#      <input type="file" id="files-5995a6ec-cd66-453f-a230-805c078e7a1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5995a6ec-cd66-453f-a230-805c078e7a1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"lesterye","key":"b4a7fecdbfcc42c451a1fb1f1d9defec"}'}

# %%
# !ls -lha kaggle.json
# Out:
# -rw------- 1 root root 64 Apr 22 04:12 kaggle.json

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# we need to set permissions
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# check your directory before downloading the datasets
# !pwd
# Out:
# /content/gdrive/MyDrive/CS424 - IP/a2/Image-Classification-ConvNeXt

# %%
# list all available datasets
# !kaggle datasets list
# Out:
# ref                                                            title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/muratkokludataset/date-fruit-datasets                 Date Fruit Datasets                              408KB  2022-04-03 09:25:39           1816        326  0.9375
# datasets/piterfm/2022-ukraine-russian-war                      2022 Ukraine Russia War                            2KB  2022-04-21 09:38:14          10271        561  1.0
# datasets/muratkokludataset/acoustic-extinguisher-fire-dataset  Acoustic Extinguisher Fire Dataset               621KB  2022-04-02 22:59:36            218        287  0.9375
# ...

# %%
# !kaggle competitions download -c image-perception-a2
# Out:
# ...
# 100% 25.3G/25.3G [05:17<00:00, 157MB/s]
# 100% 25.3G/25.3G [05:17<00:00, 85.6MB/s]

# %%
# !unzip image-perception-a2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles291.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles293.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles294.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles295.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles296.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles299.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles300.jpg
#   inflating: training/training/shredded_chicken_and_mushroom_noodles/augshreddedchickenandmushroomnoodles301.jpg
# ...
